# %% [markdown]
# Tableau Project - Analysis on Skills Rating
#
# A Tableau dashboard that analyzes a fictional group's skillset.
#
# Highlights:
#
# 1) Cleaned and pre-processed data stored in Excel spreadsheet with the help of Python.
#
# 2) Visualized this information with the help of Tableau.
# A Tableau dashboard that analyzes a fictional group's skillset.
#
# Highlights:
# 1) Cleaned and pre-processed data stored in Excel spreadsheet with the help of Python.
# 2) Visualized this information with the help of Tableau.
#
# Skills:
# Tableau · Python (Programming Language) · Microsoft Excel
#
# Link to project: https://public.tableau.com/app/profile/wenzell.guadiz/viz/Portfoliover_CompetencyRating/Dashboard
